# %%
from ripser_radii import *

# %% [markdown]
# # House

# %%
house = '../Data/house_points.txt'
select_radii(data=house,max_dim=2,min_persistence=0.5)
# Out:
# 2.414213538169861

# %% [markdown]
# Capturing a radii with that gives a 1-cycle

# %% [markdown]
# # Torus

# %%
torus = '../Data/torus_points.txt'

# %%
select_radii(data=torus,max_dim=2,min_persistence=0.5)
# Out:
# 1.5833438634872437

# %% [markdown]
# # Sphere

# %%
sphere = '../Data/sphere_points.txt'

# %%
select_radii(data=sphere,max_dim=2,min_persistence=0.7)
# Out:
# 1.0851261913776398

# %%
select_radii(data=sphere,max_dim=2,min_persistence=0.1)
# Out:
# {2: [array([0.52750629, 1.64274609])], 1: [array([0.15760303, 0.28437123]), array([0.16691206, 0.27632448]), array([0.17046714, 0.35080749]), array([0.18289371, 0.32616496]), array([0.18721302, 0.34183678]), array([0.18968955, 0.29380199]), array([0.20173126, 0.34459835]), array([0.2019757 , 0.32655531]), array([0.20399989, 0.33282545]), array([0.20566651, 0.36061746]), array([0.21053369, 0.42050108]), array([0.21060634, 0.39592442]), array([0.21124706, 0.32411921]), array([0.21401632, 0.4072485 ]), array([0.22076589, 0.3864868 ]), array([0.22347441, 0.40033889]), array([0.22592919, 0.33492076]), array([0.2299798 , 0.37971815]), array([0.23327617, 0.51762676]), array([0.23541808, 0.34081614]), array([0.25293824, 0.40259844]), array([0.2650387 , 0.38572407]), array([0.26535824, 0.48413935]), array([0.27660236, 0.41993523]), array([0.28112039, 0.40269625]), array([0.30727679, 0.43780833])]}
# [1.0851261913776398]
# [1.0851261913776398]
# 0.27632448077201843

# %%
from persim import plot_diagrams

# %%
plot_diagrams?

# %%
import matplotlib.pyplot as plt
