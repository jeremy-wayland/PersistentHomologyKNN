# %%
from ripser_radii import *

# %% [markdown]
# # Torus

# %%
data = '../Data/torus_points.txt'

# %%
select_radii(data,max_dim=2,min_persistence=0.5)
# Out:
# 2
# Trimmed dictionary: {1: [array([0.37699175, 1.60837221]), array([0.37756079, 1.58334386])]}
# 1
# Im printing my persistence dictionary: {1: [array([0.37699175, 1.60837221]), array([0.37756079, 1.58334386])]}
# Intersection, new interval: [0.37756079 1.58334386]
# The intersection is: [0.37756079 1.58334386]
# Dimension is 1
# [0.37756079 1.58334386]
# About to return, should not recurse farther
# [0.3775607943534851, 1.5833438634872437]
