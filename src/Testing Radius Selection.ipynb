# %%
from ripser_radii import *

# %% [markdown]
# # House

# %%
house = '../Data/house_points.txt'
select_radii(data=house,max_dim=2,min_persistence=0.1)
# Out:
# [2.414213538169861]

# %% [markdown]
# Capturing a radii with that gives a 1-cycle

# %% [markdown]
# # Torus

# %%
torus = '../Data/torus_points.txt'

# %%
select_radii(data=torus,max_dim=2,min_persistence=0.5)
# Out:
# [0.3775607943534851, 1.5833438634872437]

# %% [markdown]
# First value here referring to a token radius that connects dimension 1 homology and second for dimension 2.

# %% [markdown]
# # Sphere

# %%
sphere = '../Data/sphere_points.txt'

# %%
select_radii(data=sphere,max_dim=2,min_persistence=0.5)
# Out:
# No candidate intervals found. Try increasing minimum persistence threshold

# %%
select_radii(data=sphere,max_dim=2,min_persistence=0.1)
# Out:
# [0.26535823941230774, 0.27632448077201843]
